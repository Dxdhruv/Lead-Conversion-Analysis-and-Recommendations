# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
leads_df = pd.read_csv('/content/lead_data.csv')

# %%
leads_df
# Out:
#       Lead ID       Location               College Year of Study  \
# 0         LD1      Ahmedabad   Jadavpur University           1st
# 1         LD2     Trivandrum         ABC Institute           1st
# 2         LD3          Patna         ABC Institute           4th
# 3         LD4        Kolkata   University of Delhi           4th
# 4         LD5  Visakhapatnam            NIT Trichy           3rd
# ...       ...            ...                   ...           ...
# 9995   LD9996         Indore        IISc Bangalore           2nd
# 9996   LD9997     Coimbatore   Jadavpur University           1st
# 9997   LD9998       Vadodara  Jamia Millia Islamia           3rd
# 9998   LD9999        Chennai   Jadavpur University           1st
# 9999  LD10000          Delhi            NIT Trichy           4th
#
#       Program Interest            Lead Source
# 0     Electric Vehicle              Instagram
# 1      Cloud Computing  College Collaboration
# ...

# %%
location_counts = leads_df['Location'].value_counts()

# %%
location_counts
# Out:
# Location
# Chandigarh       539
# Surat            537
# Bhopal           533
# Bangalore        527
# Hyderabad        519
# Ahmedabad        517
# Indore           517
# Pune             505
# Kolkata          502
# Visakhapatnam    494
# Mumbai           493
# Nagpur           492
# Trivandrum       487
# Coimbatore       487
# Lucknow          486
# Jaipur           484
# Patna            483
# Vadodara         479
# Chennai          472
# Delhi            447
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=location_counts.index, y=location_counts.values, palette="viridis")
plt.title('Number of Leads by location')
plt.xlabel('Location')
plt.ylabel('Number of Leads')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-91-8ec535e65c3f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=location_counts.index, y=location_counts.values, palette="viridis")

# %%
program_counts = leads_df['Program Interest'].value_counts()
program_counts
# Out:
# Program Interest
# Electric Vehicle    1465
# Cyber Security      1447
# Data Science        1444
# Robotics            1434
# Machine Learning    1421
# AI                  1418
# Cloud Computing     1371
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=program_counts.index, y=program_counts.values, palette="viridis")
plt.title('Number of leads by program interest', fontsize=16)
plt.xlabel('Program Interest', fontsize=12)
plt.ylabel('Number of leads', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-93-3caa8ecc9786>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=program_counts.index, y=program_counts.values, palette="viridis")

# %%
source_counts = leads_df['Lead Source'].value_counts()
plt.figure(figsize=(10,6))
sns.barplot(x=source_counts.index, y=source_counts.values, palette="viridis")
plt.xlabel('Lead Sources')
plt.ylabel('Number of Leads')
plt.title('Number of Leads sources')
plt.show()
# Out:
# <ipython-input-94-1e124ee9571b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=source_counts.index, y=source_counts.values, palette="viridis")

# %%
location_program_counts = leads_df.groupby(['Location', 'Program Interest']).size().unstack()

# %%
location_program_counts
# Out:
# Program Interest  AI  Cloud Computing  Cyber Security  Data Science  \
# Location
# Ahmedabad         92               65              80            71
# Bangalore         70               71              79            84
# Bhopal            73               64              74            90
# Chandigarh        82               70              73            77
# Chennai           72               63              61            64
# Coimbatore        71               62              71            76
# Delhi             73               80              56            59
# Hyderabad         68               67              80            77
# Indore            76               65              74            85
# Jaipur            47               70              82            58
# Kolkata           81               55              74            64
# Lucknow           77               71              69            65
# Mumbai            56               71              75            66
# ...

# %%
location_program_counts.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Number of Leads by Location and Program Interest')
plt.xlabel('Location', fontsize=12)
plt.ylabel('Number of Leads', fontsize=12)
# plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
location_program_counts_long = location_program_counts.reset_index().melt(id_vars='Location', var_name='Program Interest', value_name='Count')
plt.figure(figsize=(12,8))
sns.barplot(data=location_program_counts_long, x='Location', y='Count', hue='Program Interest', palette='viridis')
plt.title('Program Interest by Location')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
year_program_counts = leads_df.groupby(['Year of Study', 'Program Interest']).size().unstack()

# %%
year_program_counts
# Out:
# Program Interest   AI  Cloud Computing  Cyber Security  Data Science  \
# Year of Study
# 1st               359              339             362           359
# 2nd               373              338             341           352
# 3rd               343              354             378           349
# 4th               343              340             366           384
#
# Program Interest  Electric Vehicle  Machine Learning  Robotics
# Year of Study
# 1st                            346               385       351
# 2nd                            367               377       353
# 3rd                            372               329       363
# 4th                            380               330       367

# %%
year_program_counts.plot(kind='bar', stacked=False, figsize=(10,6))
plt.title('Number of Leads by Year of Study and Program Interest')
plt.xlabel('Year of Study')
plt.ylabel('Program Interest')
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
college_program_counts = leads_df.groupby(['College', 'Program Interest']).size().unstack()
college_program_counts
# Out:
# Program Interest       AI  Cloud Computing  Cyber Security  Data Science  \
# College
# ABC Institute          75               75              66            86
# Amity University       75               67              71            79
# BITS Pilani            71               67              79            73
# Bharati Vidyapeeth     64               60              71            79
# IISc Bangalore         79               71              76            66
# IIT Bombay             78               66              77            76
# IIT Delhi              67               64              76            73
# Jadavpur University    65               66              73            61
# Jamia Millia Islamia   78               77              58            45
# MIT Pune               63               74              66            77
# Manipal University     66               61              81            80
# NIT Trichy             80               73              81            68
# ...

# %%
college_program_counts.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Leads by College and Program Interest')
plt.xlabel('College')
plt.ylabel('Number of Leads')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
source_program_counts = leads_df.groupby(['Lead Source','Program Interest']).size().unstack()
source_program_counts
# Out:
# Program Interest        AI  Cloud Computing  Cyber Security  Data Science  \
# Lead Source
# College Collaboration  154              136             157           162
# Email                  146              165             155           173
# Facebook               154              168             166           162
# Google Form            146              144             140           174
# Instagram              180              158             156           168
# LinkedIn               177              149             160           126
# Mass-Mailing           160              153             191           146
# Referral               157              153             166           175
# WhatsApp               144              145             156           158
#
# Program Interest       Electric Vehicle  Machine Learning  Robotics
# Lead Source
# College Collaboration               161               161       157
# ...

# %%
source_program_counts.plot(kind='bar', figsize=(10,6))
plt.title('Leads source by Program Interest')
plt.xlabel('Lead Source')
plt.ylabel('Number of Leads')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
location_source_counts = leads_df.groupby(['Location','Lead Source']).size().unstack()
location_source_counts
# Out:
# Lead Source    College Collaboration  Email  Facebook  Google Form  Instagram  \
# Location
# Ahmedabad                         61     51        65           57         58
# Bangalore                         69     60        68           47         69
# Bhopal                            45     58        68           59         65
# Chandigarh                        47     63        50           59         67
# Chennai                           52     55        50           47         48
# Coimbatore                        54     62        55           58         54
# Delhi                             50     48        46           43         64
# Hyderabad                         53     55        56           64         51
# Indore                            46     59        68           54         63
# Jaipur                            58     49        58           52         44
# Kolkata                           48     47        64           58         62
# ...

# %%
location_source_counts.plot(kind='bar', figsize=(10,6))
plt.title('Lead sources by location')
plt.xlabel('Location')
plt.ylabel('Lead Sources')
# plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
college_source_counts = leads_df.groupby(['College','Lead Source']).size().unstack()
college_source_counts
# Out:
# Lead Source            College Collaboration  Email  Facebook  Google Form  \
# College
# ABC Institute                             46     56        49           69
# Amity University                          56     54        58           58
# BITS Pilani                               64     58        64           46
# Bharati Vidyapeeth                        60     58        57           51
# IISc Bangalore                            57     54        61           65
# IIT Bombay                                62     53        55           55
# IIT Delhi                                 62     40        54           45
# Jadavpur University                       42     64        54           49
# Jamia Millia Islamia                      50     42        65           45
# MIT Pune                                  54     61        74           47
# Manipal University                        55     66        49           59
# ...

# %%
college_source_counts.plot(kind='bar', figsize=(10,6), stacked=False, colormap='Set1')
plt.title('Lead Sources by College', fontsize='16')
plt.xlabel('Collge')
plt.ylabel('Number of Leads')
plt.show()

# %%
year_source_counts = leads_df.groupby(['Year of Study', 'Lead Source']).size().unstack()
year_source_counts.plot(kind='bar', stacked='False', figsize=(10,6), colormap='Paired')
plt.title('Lead Sources by year of study')
plt.xlabel('Year of Study')
plt.ylabel('Number of Leads')
plt.show()

# %%
program_interest_percentage = leads_df['Program Interest'].value_counts(normalize=True) * 100
program_interest_percentage
# Out:
# Program Interest
# Electric Vehicle    14.65
# Cyber Security      14.47
# Data Science        14.44
# Robotics            14.34
# Machine Learning    14.21
# AI                  14.18
# Cloud Computing     13.71
# Name: proportion, dtype: float64

# %%
program_interest_percentage.plot(kind='bar', figsize=(10,6))
plt.title('Percentage Distribution of Leads by E-learning Program')
plt.xlabel('E-Learning Program')
plt.ylabel('Percentage by Leads')
plt.show()

# %%
top_colleges = leads_df['College'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_colleges.values, y=top_colleges.index, palette="magma")
plt.title('Top Colleges Contributing Leads', fontsize=16)
plt.xlabel('Number of Leads', fontsize=12)
plt.ylabel('College', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-76-7d2830651f5d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_colleges.values, y=top_colleges.index, palette="magma")

# %%
location_counts = leads_df['Location'].value_counts().head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=location_counts.index, y=location_counts.values, palette="viridis")
plt.title('Location Wise Lead Distribution')
plt.ylabel('Number of Leads')
plt.xlabel('Location')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-79-617f2d73e54e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=location_counts.index, y=location_counts.values, palette="viridis")

# %%
lead_source_program = leads_df.groupby(['Lead Source','Program Interest']).size().unstack()

# %%
lead_source_program
# Out:
# Program Interest        AI  Cloud Computing  Cyber Security  Data Science  \
# Lead Source
# College Collaboration  154              136             157           162
# Email                  146              165             155           173
# Facebook               154              168             166           162
# Google Form            146              144             140           174
# Instagram              180              158             156           168
# LinkedIn               177              149             160           126
# Mass-Mailing           160              153             191           146
# Referral               157              153             166           175
# WhatsApp               144              145             156           158
#
# Program Interest       Electric Vehicle  Machine Learning  Robotics
# Lead Source
# College Collaboration               161               161       157
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(lead_source_program, annot=True, fmt="d", cmap="coolwarm", linewidths=0.5)
plt.title('Lead Source vs Program Interest')
plt.xlabel('Program Interest')
plt.ylabel('Lead Source')
plt.show()
